# %%
import pandas as pd
data = pd.read_csv('output.csv')#, columns=['number of errors', 'probability'])

# %%
# data

# %%
# data.columns
d1 = data[:]#[(data["number_of_errors"]>190) & (data["number_of_errors"]<280)]

d1.plot(x='number_of_errors', y='probability')
import matplotlib.pyplot as plt
plt.show()
